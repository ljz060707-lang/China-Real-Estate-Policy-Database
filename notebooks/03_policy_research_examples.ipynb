# %% [markdown]
# # 政策趋势、地区比较与论文面板

# %%
from policydb import PolicyDB

db = PolicyDB.open("..")
monthly = db.research.city_month_panel()
yearly = db.research.city_year_panel()
events = db.research.event_window("purchase_restriction")
monthly.head(), yearly.head(), events.head()
